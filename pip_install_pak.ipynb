# %%
# !pip install opencv-python
# !pip install matplotlib
# !pip install pandas
# !pip install numpy

import cv2
import datetime
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
# Out:
# ...
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached numpy-1.26.4-cp39-cp39-win_amd64.whl.metadata (61 kB)
# Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
# Using cached numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
# ...
#      ---------------------------------------- 0.0/162.3 kB ? eta -:--:--
#      ----------------------------------- -- 153.6/162.3 kB 3.1 MB/s eta 0:00:01
#      -------------------------------------- 162.3/162.3 kB 3.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    - -------------------------------------- 0.2/7.6 MB 4.6 MB/s eta 0:00:02
#    -- ------------------------------------- 0.5/7.6 MB 4.8 MB/s eta 0:00:02
#    --- ------------------------------------ 0.7/7.6 MB 5.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.1/7.6 MB 5.7 MB/s eta 0:00:02
#    ------ --------------------------------- 1.2/7.6 MB 5.6 MB/s eta 0:00:02
# ...
